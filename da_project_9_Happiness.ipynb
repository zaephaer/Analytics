# %% [markdown]
# <a href="https://colab.research.google.com/github/zaephaer/Analytics/blob/main/da_project_9_Happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Data Analysis Project 9: World Happiness 2021 Dataset**
# The World Happiness Report may be a point of interest survey of the state of worldwide bliss. The primary report was distributed in 2012, the second in 2013, the third in 2015, and the fourth within the 2016 Upgrade. The World Joy 2017, which positions 155 nations by their bliss levels, was discharged at the Joined together Countries at an occasion celebrating Universal Day of Joy on Walk 20th. The report proceeds to pick up worldwide acknowledgment as governments, organizations and respectful society progressively utilize joy pointers to educate their policy-making choices. Driving specialists over areas – financial matters, brain research, overview investigation, national insights, wellbeing, open approach and more – depict how estimations of well-being can be used effectively to evaluate the advance of countries. The reports survey the state of bliss within the world nowadays and appear how the modern science of bliss clarifies individual and national varieties in bliss.

# %% [markdown]
# 2021 Data retrieve from: https://drive.google.com/file/d/1_FYpYjzX3Yiqpp2l0KuczJW6UyD1B7s4/view?usp=sharing<br>
# 2022 Data retrieve from: https://drive.google.com/file/d/1gF6V1NnQg4y0GMDyrWy2bGkMCMZnDmCk/view?usp=sharing

# %%
#importing libraries
import pandas as pd

# %%
#loading dataset directly from Google Drive
url = 'https://drive.google.com/file/d/1_FYpYjzX3Yiqpp2l0KuczJW6UyD1B7s4/view?usp=sharing'     #whr-2021
#url = 'https://drive.google.com/file/d/1gF6V1NnQg4y0GMDyrWy2bGkMCMZnDmCk/view?usp=sharing'      #whr-2022
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
df = pd.read_csv(dwn_url)
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# ### 1. Selected column

# %%
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
selcol = ['Country name','Regional indicator','Ladder score','Logged GDP per capita', 'Social support', 
          'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption']

# %%
#makes new dataframe with selected columns
df = df[selcol].copy()
df.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# ...

# %% [markdown]
# ### 2. Rename columns

# %%
#data.rename(columns={'gdp':'log(gdp)'}, inplace=True)
df.rename(columns = {'Country name':'Country', 'Regional indicator':'Region','Ladder score':'Happines','Logged GDP per capita':'GDP_percapita',
                     'Social support':'Social_support','Healthy life expectancy':'Healthlife',
                     'Freedom to make life choices':'Freedomlife','Perceptions of corruption':'Corruption_perception'}, inplace = True)
df.head()
# Out:
#        Country          Region  Happines  GDP_percapita  Social_support  \
# 0      Finland  Western Europe     7.842         10.775           0.954
# 1      Denmark  Western Europe     7.620         10.933           0.954
# 2  Switzerland  Western Europe     7.571         11.117           0.942
# 3      Iceland  Western Europe     7.554         10.878           0.983
# 4  Netherlands  Western Europe     7.464         10.932           0.942
#
#    Healthlife  Freedomlife  Generosity  Corruption_perception
# 0        72.0        0.949      -0.098                  0.186
# 1        72.7        0.946       0.030                  0.179
# 2        74.4        0.919       0.025                  0.292
# 3        73.0        0.955       0.160                  0.673
# 4        72.4        0.913       0.175                  0.338

# %% [markdown]
# ### 3. Check Null value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                149 non-null    object
#  1   Region                 149 non-null    object
#  2   Happines               149 non-null    float64
#  3   GDP_percapita          149 non-null    float64
#  4   Social_support         149 non-null    float64
#  5   Healthlife             149 non-null    float64
#  6   Freedomlife            149 non-null    float64
#  7   Generosity             149 non-null    float64
#  8   Corruption_perception  149 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 10.6+ KB

# %% [markdown]
# ### 3. Using '.describe()' to view statistical information

# %%
df.describe()
# Out:
#          Happines  GDP_percapita  Social_support  Healthlife  Freedomlife  \
# count  149.000000     149.000000      149.000000  149.000000   149.000000
# mean     5.532839       9.432208        0.814745   64.992799     0.791597
# std      1.073924       1.158601        0.114889    6.762043     0.113332
# min      2.523000       6.635000        0.463000   48.478000     0.382000
# 25%      4.852000       8.541000        0.750000   59.802000     0.718000
# 50%      5.534000       9.569000        0.832000   66.603000     0.804000
# 75%      6.255000      10.421000        0.905000   69.600000     0.877000
# max      7.842000      11.647000        0.983000   76.953000     0.970000
#
#        Generosity  Corruption_perception
# count  149.000000             149.000000
# mean    -0.015134               0.727450
# std      0.150657               0.179226
# min     -0.288000               0.082000
# 25%     -0.126000               0.667000
# 50%     -0.036000               0.781000
# ...

# %% [markdown]
# ### 4. Exploring unique 'Region'

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America and ANZ',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
df['Region'].nunique()
# Out:
# 10

# %% [markdown]
# ### 5. Count number of 'Country' in every 'Region'

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Region, dtype: int64

# %% [markdown]
# ### 6. 'Country' with 'Happines' > 7

# %%
df[df['Happines'] > 7]
# Out:
#            Country                        Region  Happines  GDP_percapita  \
# 0          Finland                Western Europe     7.842         10.775
# 1          Denmark                Western Europe     7.620         10.933
# 2      Switzerland                Western Europe     7.571         11.117
# 3          Iceland                Western Europe     7.554         10.878
# 4      Netherlands                Western Europe     7.464         10.932
# 5           Norway                Western Europe     7.392         11.053
# 6           Sweden                Western Europe     7.363         10.867
# 7       Luxembourg                Western Europe     7.324         11.647
# 8      New Zealand         North America and ANZ     7.277         10.643
# 9          Austria                Western Europe     7.268         10.906
# 10       Australia         North America and ANZ     7.183         10.796
# 11          Israel  Middle East and North Africa     7.157         10.575
# ...

# %%
#Count number of country
len(df[df['Happines'] > 7])
# Out:
# 17

# %% [markdown]
# ### 7. 'Country' with 'Happiness' < 4

# %%
df[df['Happines'] < 4]
# Out:
#           Country                        Region  Happines  GDP_percapita  \
# 137  Sierra Leone            Sub-Saharan Africa     3.849          7.434
# 138         India                    South Asia     3.819          8.755
# 139       Burundi            Sub-Saharan Africa     3.775          6.635
# 140         Yemen  Middle East and North Africa     3.658          7.578
# 141      Tanzania            Sub-Saharan Africa     3.623          7.876
# 142         Haiti   Latin America and Caribbean     3.615          7.477
# 143        Malawi            Sub-Saharan Africa     3.600          6.958
# 144       Lesotho            Sub-Saharan Africa     3.512          7.926
# 145      Botswana            Sub-Saharan Africa     3.467          9.782
# 146        Rwanda            Sub-Saharan Africa     3.415          7.676
# 147      Zimbabwe            Sub-Saharan Africa     3.145          7.943
# 148   Afghanistan                    South Asia     2.523          7.695
#
# ...

# %%
df[df['Happines'] < 4].shape[0]
# Out:
# 12

# %% [markdown]
# ### 8. GDP > 11

# %%
df[df['GDP_percapita'] > 11][['Country','GDP_percapita']].sort_values(by = 'GDP_percapita', ascending = False)
# Out:
#                  Country  GDP_percapita
# 7             Luxembourg         11.647
# 31             Singapore         11.488
# 14               Ireland         11.342
# 2            Switzerland         11.117
# 24  United Arab Emirates         11.085
# 5                 Norway         11.053
# 18         United States         11.023

# %% [markdown]
# ### 9. GDP < 7.5

# %%
df[df['GDP_percapita'] < 7.5][['Country','GDP_percapita']].sort_values(by = 'GDP_percapita', ascending = False)
# Out:
#           Country  GDP_percapita
# 142         Haiti          7.477
# 137  Sierra Leone          7.434
# 134    Madagascar          7.396
# 127          Chad          7.364
# 135          Togo          7.362
# 119       Liberia          7.288
# 114    Mozambique          7.158
# 95          Niger          7.098
# 143        Malawi          6.958
# 139       Burundi          6.635

# %% [markdown]
# ### 10. Corruption Perception > 0.9

# %%
df[df['Corruption_perception'] > 0.9][['Country','Corruption_perception']].sort_values(by = 'Corruption_perception', ascending = False)
# Out:
#                     Country  Corruption_perception
# 59                  Croatia                  0.939
# 45                  Romania                  0.938
# 87                 Bulgaria                  0.932
# 63   Bosnia and Herzegovina                  0.931
# 109                 Ukraine                  0.924
# 148             Afghanistan                  0.924
# 64                  Moldova                  0.918
# 32                   Kosovo                  0.917
# 144                 Lesotho                  0.915
# 33                 Slovakia                  0.911
# 66               Kyrgyzstan                  0.908
# 93          North Macedonia                  0.905
# 92                  Albania                  0.901

# %% [markdown]
# ### 11. Corruption Perception < 0.3

# %%
df[df['Corruption_perception'] < 0.3][['Country','Corruption_perception']].sort_values(by = 'Corruption_perception', ascending = False)
# Out:
#          Country  Corruption_perception
# 2    Switzerland                  0.292
# 5         Norway                  0.270
# 8    New Zealand                  0.242
# 6         Sweden                  0.237
# 0        Finland                  0.186
# 1        Denmark                  0.179
# 146       Rwanda                  0.167
# 31     Singapore                  0.082

# %% [markdown]
# ### 12. Is 'Malaysia' Happiness Higher or Lower than World Average?

# %%
df[df['Country'] == 'Malaysia']
# Out:
#      Country          Region  Happines  GDP_percapita  Social_support  \
# 80  Malaysia  Southeast Asia     5.384         10.238           0.817
#
#     Healthlife  Freedomlife  Generosity  Corruption_perception
# 80      67.102        0.895       0.125                  0.839

# %%
df['Happines'].mean()
# Out:
# 5.532838926174494

# %%
#df.iloc[[row_index],[column_index]]
df.iloc[[80],[2]].shape[0] > df['Happines'].mean()
# Out:
# False

# %% [markdown]
# ### 13. Is 'Malaysia' GDP Higher or Lower than World Average?

# %%
df.iloc[[80],[3]].shape[0] > df['GDP_percapita'].mean()
# Out:
# False

# %% [markdown]
# ### 14. Is 'Malaysia' Corruption Perception Higher or Lower than World Average?

# %%
df.iloc[[80],[8]].shape[0] > df['Corruption_perception'].mean()
# Out:
# True

# %% [markdown]
# ### 15. Mean for each column Groupby 'Region'

# %%
df.groupby('Region').mean()
# Out:
#                                     Happines  GDP_percapita  Social_support  \
# Region
# Central and Eastern Europe          5.984765      10.109059        0.887412
# Commonwealth of Independent States  5.467000       9.401833        0.872500
# East Asia                           5.810333      10.367667        0.860500
# Latin America and Caribbean         5.908050       9.370000        0.839500
# Middle East and North Africa        5.219765       9.666118        0.797647
# North America and ANZ               7.128500      10.809500        0.933500
# South Asia                          4.441857       8.682571        0.703429
# Southeast Asia                      5.407556       9.421444        0.820333
# Sub-Saharan Africa                  4.494472       8.075194        0.696750
# Western Europe                      6.914905      10.822714        0.914476
#
#                                     Healthlife  Freedomlife  Generosity  \
# Region
# ...

# %% [markdown]
# ### 16. Mean on specific column groupby 'Region'

# %%
#on 'Happiness'
df.groupby('Region').Happines.mean().sort_values(ascending = False)
# Out:
# Region
# North America and ANZ                 7.128500
# Western Europe                        6.914905
# Central and Eastern Europe            5.984765
# Latin America and Caribbean           5.908050
# East Asia                             5.810333
# Commonwealth of Independent States    5.467000
# Southeast Asia                        5.407556
# Middle East and North Africa          5.219765
# Sub-Saharan Africa                    4.494472
# South Asia                            4.441857
# Name: Happines, dtype: float64

# %%
#on 'Corruption Perception'
df.groupby('Region').Corruption_perception.mean().sort_values(ascending = False).plot.bar()

# %% [markdown]
# ### 17. 'Region' = 'Southeast Asia' and 'Happines' > World Average

# %%
#df[df['Region'] == 'Southeast Asia']       #condition 1
#df[df['Happines'] > df['Happines'].mean()] #condition 2
df[(df['Region'] == 'Southeast Asia') & (df['Happines'] > df['Happines'].mean())]
# Out:
#         Country          Region  Happines  GDP_percapita  Social_support  \
# 31    Singapore  Southeast Asia     6.377         11.488           0.915
# 53     Thailand  Southeast Asia     5.985          9.805           0.888
# 60  Philippines  Southeast Asia     5.880          9.076           0.830
#
#     Healthlife  Freedomlife  Generosity  Corruption_perception
# 31      76.953        0.927      -0.018                  0.082
# 53      67.401        0.884       0.287                  0.895
# 60      62.000        0.917      -0.097                  0.742

# %% [markdown]
# ### 18. 'Region' = 'Southeast Asia' and 'GDP Percapita' > World Average

# %%
df[(df['Region'] == 'Southeast Asia') & (df['GDP_percapita'] > df['GDP_percapita'].mean())]
# Out:
#       Country          Region  Happines  GDP_percapita  Social_support  \
# 31  Singapore  Southeast Asia     6.377         11.488           0.915
# 53   Thailand  Southeast Asia     5.985          9.805           0.888
# 80   Malaysia  Southeast Asia     5.384         10.238           0.817
#
#     Healthlife  Freedomlife  Generosity  Corruption_perception
# 31      76.953        0.927      -0.018                  0.082
# 53      67.401        0.884       0.287                  0.895
# 80      67.102        0.895       0.125                  0.839

# %% [markdown]
# ### 19. 'Region' = 'Southeast Asia' and 'Corruption Perception' < World Average

# %%
df[(df['Region'] == 'Southeast Asia') & (df['Corruption_perception'] < df['Corruption_perception'].mean())]
# Out:
#        Country          Region  Happines  GDP_percapita  Social_support  \
# 31   Singapore  Southeast Asia     6.377         11.488           0.915
# 99        Laos  Southeast Asia     5.030          8.947           0.728
# 125    Myanmar  Southeast Asia     4.426          8.541           0.779
#
#      Healthlife  Freedomlife  Generosity  Corruption_perception
# 31       76.953        0.927      -0.018                  0.082
# 99       58.968        0.910       0.123                  0.658
# 125      59.302        0.876       0.509                  0.660

# %%
#additional libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#set style
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10,7)
plt.rcParams['figure.facecolor'] = '#FFE5B4'

# %% [markdown]
# ### 20. Scatter Plot 'Happiness' vs 'GDP' by 'Region'

# %%
plt.rcParams['figure.figsize'] = (15,7)
plt.title('Scatter Plot: Happiness vs GDP')
sns.scatterplot(x = df['Happines'], y = df['GDP_percapita'], hue = df['Region'])

plt.legend(loc = 'upper left', fontsize = '9')
plt.xlabel('Happiness Score', fontsize = '10')
plt.ylabel('GDP per capita', fontsize = '10')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# ### 21. Correlation Heatmap between columns

# %%
cor = df.corr(method = "pearson")
f, ax = plt.subplots(figsize = (10,5))
sns.heatmap(cor, mask = np.zeros_like(cor, dtype = np.bool), cmap="Blues", square = True, ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.corr()
# Out:
#                        Happines  GDP_percapita  Social_support  Healthlife  \
# Happines               1.000000       0.789760        0.756888    0.768099
# GDP_percapita          0.789760       1.000000        0.785299    0.859461
# Social_support         0.756888       0.785299        1.000000    0.723256
# Healthlife             0.768099       0.859461        0.723256    1.000000
# Freedomlife            0.607753       0.432323        0.482930    0.461494
# Generosity            -0.017799      -0.199286       -0.114946   -0.161750
# Corruption_perception -0.421140      -0.342337       -0.203207   -0.364374
#
#                        Freedomlife  Generosity  Corruption_perception
# Happines                  0.607753   -0.017799              -0.421140
# GDP_percapita             0.432323   -0.199286              -0.342337
# Social_support            0.482930   -0.114946              -0.203207
# Healthlife                0.461494   -0.161750              -0.364374
# ...
